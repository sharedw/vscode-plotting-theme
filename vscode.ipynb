# %%
import os
import json
import re
import matplotlib.pyplot as plt

# %%
plt.plot([4,5,6], [3,8,5])

# %%
import get_theme
def basic_matplotlib():
    plt.plot([4,5,6], [3,8,5], label='series1') #comment
    plt.plot([1,2,6],[4,5,6], label='series2')
    plt.xlabel('Important Label')
    plt.ylabel('More important')
    plt.title('VERY important')
    plt.legend()
basic_matplotlib()
# Out:
# Catppuccin Latte
# Catppuccin Latte
# Found theme: Catppuccin Latte in folder: C:\Users\Sharedw/.vscode/extensions/catppuccin.catppuccin-vsc-3.16.0./themes/latte.json
# #8839ef #eff1f5 #8839ef #4c4f69
