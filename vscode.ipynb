# %%
import seaborn as sns
import matplotlib.pyplot as plt


def basic_matplotlib():
    plt.plot([4,5,6], [3,8,5], label='series1') #comment
    plt.plot([1,2,6],[4,5,6], label='series2')
    plt.xlabel('Important Label')
    plt.ylabel('More important')
    plt.title('VERY important')
    plt.scatter([1,2,3],[4.5,5.5,6.5], label='points')
    plt.legend()

# %%
basic_matplotlib()

# %%
import set_theme #noqa
basic_matplotlib()
# Out:
# Nostromo UI

# %%
tips = sns.load_dataset('tips', )

sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
